# %% [markdown]
# # LeetCode Problem Analysis Template
#
# Use this notebook to keep every LeetCode analysis consistent.
#
# Replace the placeholders below with the problem number, title, difficulty, link, and your notes.
#
# ---
#
# ## Problem Metadata
#
# | Field | Value |
# |---|---|
# | Problem Number |  |
# | Problem Title |  |
# | Difficulty |  |
# | LeetCode Link |  |
# | Date Started |  |
# | Date Completed |  |
# | Pattern / Topic |  |
# | Status | Not Started / In Progress / Completed |

# %% [markdown]
# ## 1. Problem Summary
#
# Write a short explanation of the problem in your own words.
#
# The goal is to prove that you understand the task before writing code.
#
# ### What is the input?
#
# ### What is the output?
#
# ### What are the key constraints?
#
# ### Important examples
#
# ```text
# Example input:
#
# Example output:
#
# Explanation:
# ```

# %% [markdown]
# ## 2. Initial Thoughts
#
# Write your first reaction to the problem.
#
# Useful prompts:
#
# - What pattern does this look like?
# - Does it need a hash map, two pointers, sliding window, stack, recursion, dynamic programming, graph traversal, etc.?
# - What would the brute force solution be?
# - What edge cases should I watch out for?

# %%
# Imports

from typing import List, Optional, Dict, Set, Tuple
from collections import defaultdict, Counter, deque
import heapq
import math

# %% [markdown]
# ## 3. My Original Solution
#
# Write your first working solution here.
#
# This does not need to be perfect. The goal is to preserve your original thinking.

# %%
class MySolution:
    def solve(self):
        """
        Replace this method with the actual LeetCode method signature.

        Example:
        def twoSum(self, nums: List[int], target: int) -> List[int]:
            pass
        """
        pass

# %% [markdown]
# ## 4. Test Cases for My Original Solution
#
# Add normal cases, edge cases, and tricky cases.
#
# Try to include:
#
# - Example cases from LeetCode
# - Small input
# - Large input idea
# - Empty or minimal input, if allowed
# - Duplicate values
# - Boundary conditions

# %%
# Manual test cases

def run_my_solution_tests():
    solution = MySolution()

    # Replace these with real tests.
    # Example:
    # assert solution.twoSum([2, 7, 11, 15], 9) == [0, 1]

    print("All MySolution tests passed.")


run_my_solution_tests()

# %% [markdown]
# ## 5. Explanation of My Original Solution
#
# Explain how your solution works step by step.
#
# ### Core idea
#
# ### Why it works
#
# ### Where it may be inefficient
#
# ### Time complexity
#
# ```text
# O()
# ```
#
# ### Space complexity
#
# ```text
# O()
# ```

# %% [markdown]
# ## 6. Optimized or Alternative Solution
#
# Use this section for a cleaner, faster, or more standard solution.
#
# This can be your improved solution, a solution learned from discussion, or a comparison solution generated analytically.

# %%
class OptimizedSolution:
    def solve(self):
        """
        Replace this method with the actual LeetCode method signature.
        """
        pass

# %% [markdown]
# ## 7. Test Cases for Optimized Solution
#
# Run the same tests against the optimized solution.

# %%
def run_optimized_solution_tests():
    solution = OptimizedSolution()

    # Replace these with real tests.
    # Example:
    # assert solution.twoSum([2, 7, 11, 15], 9) == [0, 1]

    print("All OptimizedSolution tests passed.")


run_optimized_solution_tests()

# %% [markdown]
# ## 8. Side-by-Side Comparison
#
# | Category | My Original Solution | Optimized / Alternative Solution |
# |---|---|---|
# | Main idea |  |  |
# | Time complexity |  |  |
# | Space complexity |  |  |
# | Readability |  |  |
# | Edge-case handling |  |  |
# | Main tradeoff |  |  |
#
# ### Which solution is better and why?
#
# Write a short paragraph comparing the two approaches.

# %% [markdown]
# ## 9. Pattern Recognition
#
# Identify the broader pattern.
#
# Examples:
#
# - Hash map
# - Two pointers
# - Sliding window
# - Binary search
# - Stack
# - Monotonic stack
# - Linked list
# - Tree DFS
# - Tree BFS
# - Graph DFS
# - Graph BFS
# - Dynamic programming
# - Greedy
# - Backtracking
# - Heap / priority queue
# - Prefix sum
# - Union find
# - Trie
# - Bit manipulation
#
# ### Pattern used in this problem
#
# ### How I can recognize this pattern next time

# %% [markdown]
# ## 10. Edge Cases
#
# List important edge cases and explain whether the solution handles them.
#
# | Edge Case | Expected Behavior | Covered? |
# |---|---|---|
# |  |  |  |
# |  |  |  |
# |  |  |  |

# %% [markdown]
# ## 11. Mistakes, Bugs, or Confusions
#
# Use this section honestly.
#
# Examples:
#
# - I forgot to update a pointer.
# - I used a list when a set would be faster.
# - I missed a duplicate-value edge case.
# - I misunderstood the input constraint.
# - I overcomplicated the solution.
#
# ### Mistakes
#
# ### How I fixed them

# %% [markdown]
# ## 12. Final Clean Solution
#
# Paste the final version you would keep in the repository.

# %%
class Solution:
    def solve(self):
        """
        Final clean solution.
        Replace this method with the actual LeetCode method signature.
        """
        pass

# %% [markdown]
# ## 13. Final Notes
#
# ### Key insight
#
# ### What I learned
#
# ### What to remember for future problems
#
# ### Similar problems to try next

# %% [markdown]
# ## 14. Repository Update Checklist
#
# Before committing this problem to GitHub:
#
# - [ ] Filled in problem metadata
# - [ ] Wrote problem summary in my own words
# - [ ] Added original solution
# - [ ] Added optimized or alternative solution
# - [ ] Added test cases
# - [ ] Wrote complexity analysis
# - [ ] Compared both approaches
# - [ ] Documented mistakes or lessons learned
# - [ ] Updated `progress.md`
# - [ ] Committed changes to GitHub
